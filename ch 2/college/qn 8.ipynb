# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
df=pd.read_csv("data.csv")

# %%
df.head(2)
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
#
#    s_f_ratio  perc_alumni  expend  grad_rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56

# %%
df.describe()
# Out:
#                apps        accept       enroll   top10perc   top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         f_undergrad   p_undergrad      outstate   room_board        books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
corr_m=df.corr()

# %%
#plotting our correlation matrix
corr_m['CRIM']
# Out:
#                  apps    accept    enroll  top10perc  top25perc  f_undergrad  \
# apps         1.000000  0.943451  0.846822   0.338834   0.351640     0.814491
# accept       0.943451  1.000000  0.911637   0.192447   0.247476     0.874223
# enroll       0.846822  0.911637  1.000000   0.181294   0.226745     0.964640
# top10perc    0.338834  0.192447  0.181294   1.000000   0.891995     0.141289
# top25perc    0.351640  0.247476  0.226745   0.891995   1.000000     0.199445
# f_undergrad  0.814491  0.874223  0.964640   0.141289   0.199445     1.000000
# p_undergrad  0.398264  0.441271  0.513069  -0.105356  -0.053577     0.570512
# outstate     0.050159 -0.025755 -0.155477   0.562331   0.489394    -0.215742
# room_board   0.164939  0.090899 -0.040232   0.371480   0.331490    -0.068890
# books        0.132559  0.113525  0.112711   0.118858   0.115527     0.115550
# personal     0.178731  0.200989  0.280929  -0.093316  -0.080810     0.317200
# ...

# %%
#plotting heatmap visually
fig, ax = plt.subplots(figsize=(14,14))
cmap = sb.diverging_palette(220,20,as_cmap=True)
sb.heatmap(corr_m,annot=True,cmap=cmap)
plt.show()

# %%
#boxplot plotting
sb.boxplot(x=df['private'], y=df['outstate']);

# %%
df.columns
# Out:
# Index(['private', 'apps', 'accept', 'enroll', 'top10perc', 'top25perc',
#        'f_undergrad', 'p_undergrad', 'outstate', 'room_board', 'books',
#        'personal', 'phd', 'terminal', 's_f_ratio', 'perc_alumni', 'expend',
#        'grad_rate'],
#       dtype='object')

# %%
#add an elite column here
df['Elite'] = df['top10perc'] > 50

# %%
df.columns
# Out:
# Index(['private', 'apps', 'accept', 'enroll', 'top10perc', 'top25perc',
#        'f_undergrad', 'p_undergrad', 'outstate', 'room_board', 'books',
#        'personal', 'phd', 'terminal', 's_f_ratio', 'perc_alumni', 'expend',
#        'grad_rate', 'Elite'],
#       dtype='object')

# %%
df["Elite"].sum()
# Out:
# 78

# %%
df.head(10)
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
# 5     Yes   587     479     158         38         62          678
# 6     Yes   353     340     103         17         45          416
# 7     Yes  1899    1720     489         37         68         1594
# 8     Yes  1038     839     227         30         63          973
# 9     Yes   582     498     172         21         44          799
#
#    p_undergrad  outstate  room_board  books  personal  phd  terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# ...

# %%
#boxplot of elite and outstate
sb.boxplot(x=df['Elite'], y=df['outstate'])
# Out:
# <AxesSubplot:xlabel='Elite', ylabel='outstate'>

# %%
sb.boxplot(x=df['private'], y=df['grad_rate'])
plt.show()

# %%
sb.boxplot(x=df['Elite'], y=df['grad_rate'])
# Out:
# <AxesSubplot:xlabel='Elite', ylabel='grad_rate'>

# %%
sb.boxplot(x=df['private'], y=df['expend'])
# Out:
# <AxesSubplot:xlabel='private', ylabel='expend'>

# %%
df.shape
# Out:
# (777, 19)

# %%
df["percac"]=np.nan
df["percenroll"]=np.nan

# %%
for x in range(777):
          df['percac'][x]= 100*(df["apps"][x]-df["accept"][x])/df["apps"][x]
          df["percenroll"][x]=100*(df["accept"][x]-df["enroll"][x])/df["accept"][x]
# Out:
# <ipython-input-19-7a76e1602a53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percac'][x]= 100*(df["apps"][x]-df["accept"][x])/df["apps"][x]
# <ipython-input-19-7a76e1602a53>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["percenroll"][x]=100*(df["accept"][x]-df["enroll"][x])/df["accept"][x]

# %%
df.head(5)
# Out:
#   private  apps  accept  enroll  top10perc  top25perc  f_undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    p_undergrad  outstate  room_board  ...  personal  phd  terminal  s_f_ratio  \
# 0          537      7440        3300  ...      2200   70        78       18.1
# 1         1227     12280        6450  ...      1500   29        30       12.2
# 2           99     11250        3750  ...      1165   53        66       12.9
# 3           63     12960        5450  ...       875   92        97        7.7
# 4          869      7560        4120  ...      1500   76        72       11.9
#
#    perc_alumni  expend  grad_rate  Elite     percac  percenroll
# ...

# %%
sb.boxplot(x=df['private'], y=df['percac'])
# Out:
# <AxesSubplot:xlabel='private', ylabel='percac'>

# %%
sb.boxplot(x=df['private'], y=df['percenroll'])
# Out:
# <AxesSubplot:xlabel='private', ylabel='percenroll'>
